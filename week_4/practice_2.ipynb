# %%
import pandas as pd

# %%
#a list of strings
info = ['CSC', '102', 'is', 'the', 'best', 'course', 'ever']

#call the dataframe constructor on info
df = pd.DataFrame(info)

df
# Out:
#         0
# 0     CSC
# 1     102
# 2      is
# 3     the
# 4    best
# 5  course
# 6    ever

# %%
data = {
    'Name' : ['Angela', 'Precious', 'Luis', 'Ade'],
    'Age' : [20, 21, 19, 18]
}

df = pd.DataFrame(data);

df
# Out:
#        Name  Age
# 0    Angela   20
# 1  Precious   21
# 2      Luis   19
# 3       Ade   18

# %%
data = {
    'Name' : ['Clem', 'Prince', 'Edward', 'Adele'],
    'Age' : [27, 24, 22, 32],
    'Address' : ['Abuja', 'Kano', 'Minna', 'Lagos'],
    'Qualification' : ['MSc', 'MA', 'MCA', 'PhD']
}

df = pd.DataFrame(data);

df[['Name', 'Qualification', 'Address']]
# Out:
#      Name Qualification Address
# 0    Clem           MSc   Abuja
# 1  Prince            MA    Kano
# 2  Edward           MCA   Minna
# 3   Adele           PhD   Lagos

# %%
df.iloc[1,3]
# Out:
# 'MA'

# %%
data = pd.read_csv('iris.csv');

data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df = data.iloc[0] #select first row

df
# Out:
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 0, dtype: object

# %%
df = data.head(2)

df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
# loop over rows
for index, values in data.iterrows():
    print(index);
    print(values);
# Out:
# 0
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 0, dtype: object
# 1
# sepal_length            4.9
# sepal_width             3.0
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 1, dtype: object
# 2
# sepal_length            4.7
# sepal_width             3.2
# petal_length            1.3
# petal_width             0.2
# class           Iris-setosa
# Name: 2, dtype: object
# 3
# sepal_length            4.6
# sepal_width             3.1
# petal_length            1.5
# petal_width             0.2
# class           Iris-setosa
# Name: 3, dtype: object
# 4
# sepal_length            5.0
# sepal_width             3.6
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 4, dtype: object
# 5
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# ...

# %%
#loop over columns

print(data.columns);

for col in data.columns:
    print(data[col][3]) #third element of the column
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='str')
# 4.6
# 3.1
# 1.5
# 0.2
# Iris-setosa

# %%
#save to csv file

#here, record is a dict of lists
record = {
    'Name' : ['Abel', 'Kamsi', 'Oyode', 'Chinelo'],
    'Qualification' : ['MBA', 'BCA', 'M. Tech', 'MBA'],
    'Score' : [90, 40, 80, 98]
}

df = pd.DataFrame(record);

df.to_csv('record.csv');

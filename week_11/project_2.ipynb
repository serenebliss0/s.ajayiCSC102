# %%
from abc import ABC, abstractmethod

# %%
class coup_de_escriva(ABC):

    @abstractmethod
    def Fan_page(self):
        pass

class FC_Cirok(coup_de_escriva):
    def Fan_page(self):
        return super().Fan_page()
    
class Madiba_FC(coup_de_escriva):
    def Fan_page(self):
        return super().Fan_page()
    
class Blue_Jay_FC(coup_de_escriva):
    def Fan_page(self):
        return super().Fan_page()
    
class TSG_Walker(coup_de_escriva):
    def Fan_page(self):
        return super().Fan_page()

# %%
print(
    'FC Cirok'\n
    'Madiba_FC\n
)
user_club = input('What club do you support?\n').strip().lower();

if user_club == 'fc cirok':
    pass
# Out:
# FC Cirok Madiba_FC

# %%
#an empty class
class Parrot():
    pass

obj = Parrot();

class Dog():
    attr1 = "mammal"
    attr2 = "dog"
    
    #this is giving rust era
    def fun(self):
        print("I'm a", self.attr1)
        print("I'm a", self.attr2)
        name = "Jackie"
        return name

Rodger = Dog();

Rodger.fun();
print(Rodger.attr1);
# Out:
# I'm a mammal
# I'm a dog
# mammal
